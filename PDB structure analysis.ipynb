# %%
from Bio.PDB import PDBParser, NeighborSearch, is_aa
from Bio.SeqUtils import seq1
import pandas as pd
import os
import re

# Load the PDB file
pdb_file = "7phr.pdb"  # Replace with the actual path to your file

# Extract the PDB ID from the file name
pdb_id = os.path.splitext(os.path.basename(pdb_file))[0]

parser = PDBParser(QUIET=True)
structure = parser.get_structure(pdb_id, pdb_file)

# Define a function to parse chain descriptions from the PDB file
def parse_chain_descriptions(pdb_file):
    chain_descriptions = {}
    current_description = ""
    with open(pdb_file, 'r') as f:
        for line in f:
            if line.startswith('COMPND'):
                if 'CHAIN:' in line:
                    match = re.match(r'^COMPND\s+\d+\s+CHAIN:\s+([\w, ]+);', line)
                    if match:
                        chains = match.group(1).replace(" ", "").split(',')
                        for chain_id in chains:
                            chain_descriptions[chain_id] = current_description.strip()
                        current_description = ""
                elif 'MOLECULE:' in line:
                    current_description = line.split(':')[-1].strip()
                else:
                    current_description += ' ' + line.split(':')[-1].strip()
    return chain_descriptions

# Parse chain descriptions
chain_name_mapping = parse_chain_descriptions(pdb_file)

# Extract all atoms in the structure
all_atoms = [atom for atom in structure.get_atoms() if is_aa(atom.get_parent())]

# Build the NeighborSearch object
ns = NeighborSearch(all_atoms)

# Collect all cysteine residues in the structure
cys_residues = []
for model in structure:
    for chain in model:
        for residue in chain:
            if residue.get_resname() == 'CYS':
                cys_residues.append(residue)

# Define a function to get interacting amino acids with their distances
def get_interactions(chain1, chain2, distance_threshold=4.0):
    interactions = []
    for residue1 in chain1:
        if not is_aa(residue1):
            continue
        for residue2 in chain2:
            if not is_aa(residue2):
                continue
            for atom1 in residue1:
                for atom2 in residue2:
                    distance = atom1 - atom2
                    if distance < distance_threshold:
                        interactions.append((residue1, residue2, distance))
                        break
                if (residue1, residue2, distance) in interactions:
                    break
    return interactions

# Function to get Cys-Cys interactions
def get_cys_interactions(cys_residues, disulfide_threshold=2.5, max_cys_distance=4.0):
    disulfide_interactions = []
    non_disulfide_interactions = []
    for i, residue1 in enumerate(cys_residues):
        for residue2 in cys_residues[i + 1:]:
            if 'SG' in residue1 and 'SG' in residue2:
                distance = residue1['SG'] - residue2['SG']
                print(f"Checking Cys-Cys interaction: {residue1} - {residue2}, Distance: {distance}")
                if distance < disulfide_threshold:
                    disulfide_interactions.append((residue1, residue2, distance))
                    print(f"Recorded disulfide Cys-Cys interaction: {residue1} - {residue2}, Distance: {distance}")
                elif distance < max_cys_distance:
                    non_disulfide_interactions.append((residue1, residue2, distance))
                    print(f"Recorded non-disulfide Cys-Cys interaction: {residue1} - {residue2}, Distance: {distance}")
    return disulfide_interactions, non_disulfide_interactions

# Extract chain interactions
chain_interactions = {}
chains = list(structure[0])
for i, chain1 in enumerate(chains):
    for j, chain2 in enumerate(chains):
        if i >= j:
            continue
        interactions = get_interactions(chain1, chain2)
        if interactions:
            chain_interactions[(chain1.id, chain2.id)] = interactions

# Get Cys-Cys interactions
disulfide_interactions, non_disulfide_interactions = get_cys_interactions(cys_residues)

# Prepare the interaction data in a readable format
interaction_data = []
for (chain1_id, chain2_id), interactions in chain_interactions.items():
    for res1, res2, distance in interactions:
        interaction_data.append({
            "Chain 1": chain1_id,
            "Chain 1 Description": chain_name_mapping.get(chain1_id, "Unknown"),
            "Residue 1": f"{res1.get_resname()} {res1.id[1]}",
            "Chain 2": chain2_id,
            "Chain 2 Description": chain_name_mapping.get(chain2_id, "Unknown"),
            "Residue 2": f"{res2.get_resname()} {res2.id[1]}",
            "Distance": distance
        })

# Prepare the Cys-Cys interaction data in a readable format
disulfide_interaction_data = []
for res1, res2, distance in disulfide_interactions:
    disulfide_interaction_data.append({
        "Chain 1": res1.get_parent().id,
        "Chain 1 Description": chain_name_mapping.get(res1.get_parent().id, "Unknown"),
        "Cys 1": f"{res1.get_resname()} {res1.id[1]}",
        "Chain 2": res2.get_parent().id,
        "Chain 2 Description": chain_name_mapping.get(res2.get_parent().id, "Unknown"),
        "Cys 2": f"{res2.get_resname()} {res2.id[1]}",
        "Distance": distance
    })
    print(f"Appended verified disulfide Cys-Cys interaction: {res1} - {res2}")

non_disulfide_interaction_data = []
for res1, res2, distance in non_disulfide_interactions:
    non_disulfide_interaction_data.append({
        "Chain 1": res1.get_parent().id,
        "Chain 1 Description": chain_name_mapping.get(res1.get_parent().id, "Unknown"),
        "Cys 1": f"{res1.get_resname()} {res1.id[1]}",
        "Chain 2": res2.get_parent().id,
        "Chain 2 Description": chain_name_mapping.get(res2.get_parent().id, "Unknown"),
        "Cys 2": f"{res2.get_resname()} {res2.id[1]}",
        "Distance": distance
    })
    print(f"Appended verified non-disulfide Cys-Cys interaction: {res1} - {res2}")

# Extract chain sequences and identify missing residues
chain_sequences = []
for chain in chains:
    sequence = "".join([seq1(residue.get_resname()) for residue in chain if is_aa(residue)])
    present_residues = [residue.id[1] for residue in chain if is_aa(residue)]
    all_residues = list(range(min(present_residues), max(present_residues) + 1))
    missing_residues = list(set(all_residues) - set(present_residues))
    chain_sequences.append({
        "Chain": chain.id,
        "Chain Description": chain_name_mapping.get(chain.id, "Unknown"),
        "Sequence": sequence,
        "Missing Residues": missing_residues
    })

# Create DataFrames for the interaction details
interaction_df = pd.DataFrame(interaction_data)
disulfide_interaction_df = pd.DataFrame(disulfide_interaction_data)
non_disulfide_interaction_df = pd.DataFrame(non_disulfide_interaction_data)
chain_sequence_df = pd.DataFrame(chain_sequences)

# Prepare a summary of interactions
summary_data = []
for (chain1_id, chain2_id), interactions in chain_interactions.items():
    summary_data.append({
        "Chain 1": chain1_id,
        "Chain 1 Description": chain_name_mapping.get(chain1_id, "Unknown"),
        "Chain 2": chain2_id,
        "Chain 2 Description": chain_name_mapping.get(chain2_id, "Unknown"),
        "Number of Interactions": len(interactions)
    })

# Create a DataFrame for the summary
summary_df = pd.DataFrame(summary_data)

# Ensure interaction data is not empty
if disulfide_interaction_df.empty:
    print("Warning: No disulfide Cys-Cys interactions detected.")
else:
    print("Verified disulfide Cys-Cys interactions detected and will be saved to Excel.")

if non_disulfide_interaction_df.empty:
    print("Warning: No non-disulfide Cys-Cys interactions detected.")
else:
    print("Verified non-disulfide Cys-Cys interactions detected and will be saved to Excel.")

# Save all DataFrames to an Excel file with different sheets
output_file = f"Interacting_Amino_Acids_and_Chains_{pdb_id}.xlsx"

with pd.ExcelWriter(output_file) as writer:
    interaction_df.to_excel(writer, sheet_name="Interactions", index=False)
    summary_df.to_excel(writer, sheet_name="Summary", index=False)
    disulfide_interaction_df.to_excel(writer, sheet_name="Disulfide Cys-Cys", index=False)
    non_disulfide_interaction_df.to_excel(writer, sheet_name="Non-Disulfide Cys-Cys", index=False)
    chain_sequence_df.to_excel(writer, sheet_name="Chain Sequences", index=False)

print(f"Results have been saved to '{output_file}'")
# Out:
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=90 icode= >, Distance: 2.0136656761169434
# Recorded disulfide Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=90 icode= >, Distance: 2.0136656761169434
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=133 icode= >, Distance: 43.82508087158203
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=183 icode= >, Distance: 45.11671829223633
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=205 icode= >, Distance: 55.664276123046875
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=24 icode= >, Distance: 25.96916961669922
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=92 icode= >, Distance: 24.327733993530273
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=144 icode= >, Distance: 39.489566802978516
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=188 icode= >, Distance: 37.887638092041016
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=209 icode= >, Distance: 39.286441802978516
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=244 icode= >, Distance: 57.358184814453125
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=24 icode= >, Distance: 54.00618362426758
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=65 icode= >, Distance: 55.48033142089844
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=82 icode= >, Distance: 66.1128921508789
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=85 icode= >, Distance: 68.04174041748047
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=16 icode= >, Distance: 38.70077133178711
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=52 icode= >, Distance: 39.01665496826172
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=72 icode= >, Distance: 60.10015869140625
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=75 icode= >, Distance: 61.78937530517578
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=103 icode= >, Distance: 103.58892059326172
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=27 icode= >, Distance: 54.79645919799805
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 52.99351501464844
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 62.713741302490234
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 63.5665283203125
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 84.93583679199219
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=101 icode= >, Distance: 25.18256950378418
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=164 icode= >, Distance: 24.183109283447266
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=203 icode= >, Distance: 58.86154556274414
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=259 icode= >, Distance: 58.742855072021484
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=25 icode= >, Distance: 53.71019744873047
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=80 icode= >, Distance: 55.02534103393555
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 73.80340576171875
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=27 icode= >, Distance: 66.2546157836914
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 64.37505340576172
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 66.74967193603516
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 68.53053283691406
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 92.6196517944336
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 74.58963012695312
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=133 icode= >, Distance: 44.02149200439453
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=183 icode= >, Distance: 45.339508056640625
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=205 icode= >, Distance: 55.72867202758789
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=24 icode= >, Distance: 24.061725616455078
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=92 icode= >, Distance: 22.415613174438477
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=144 icode= >, Distance: 38.93187713623047
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=188 icode= >, Distance: 37.49257278442383
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=209 icode= >, Distance: 38.657615661621094
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=244 icode= >, Distance: 57.41463088989258
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=24 icode= >, Distance: 52.55106735229492
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=65 icode= >, Distance: 54.038665771484375
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=82 icode= >, Distance: 65.43356323242188
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=85 icode= >, Distance: 67.37213897705078
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=16 icode= >, Distance: 38.44063949584961
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=52 icode= >, Distance: 38.74026870727539
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=72 icode= >, Distance: 59.43416213989258
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=75 icode= >, Distance: 61.15702438354492
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=103 icode= >, Distance: 103.08763122558594
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=27 icode= >, Distance: 53.997928619384766
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 52.18805694580078
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 61.91912078857422
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 62.81559753417969
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 84.66053009033203
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=101 icode= >, Distance: 24.554250717163086
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=164 icode= >, Distance: 23.426040649414062
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=203 icode= >, Distance: 58.331119537353516
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=259 icode= >, Distance: 58.23044967651367
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=25 icode= >, Distance: 52.509429931640625
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=80 icode= >, Distance: 53.78624725341797
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 73.56153106689453
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=27 icode= >, Distance: 65.02096557617188
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 63.13981246948242
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 66.15750885009766
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 67.9418716430664
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 91.95243072509766
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=90 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 74.39756774902344
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=183 icode= >, Distance: 2.026639938354492
# Recorded disulfide Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=183 icode= >, Distance: 2.026639938354492
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=205 icode= >, Distance: 20.832876205444336
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=24 icode= >, Distance: 45.35171890258789
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=92 icode= >, Distance: 45.07305145263672
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=144 icode= >, Distance: 16.971891403198242
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=188 icode= >, Distance: 15.280405044555664
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=209 icode= >, Distance: 18.80489158630371
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=244 icode= >, Distance: 22.820871353149414
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=24 icode= >, Distance: 47.15479278564453
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=65 icode= >, Distance: 47.223793029785156
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=82 icode= >, Distance: 35.88397216796875
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=85 icode= >, Distance: 37.437923431396484
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=16 icode= >, Distance: 42.49856185913086
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=52 icode= >, Distance: 44.44321823120117
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=72 icode= >, Distance: 44.27204513549805
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=75 icode= >, Distance: 45.292476654052734
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=103 icode= >, Distance: 75.46868133544922
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=27 icode= >, Distance: 58.12619400024414
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 56.28923797607422
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 45.93601608276367
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance:

# Checking Cys-Cys interaction: <Residue CYS het=  resseq=164 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 87.59390258789062
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=164 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 110.24459838867188
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=164 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 93.98992156982422
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=259 icode= >, Distance: 2.032108783721924
# Recorded disulfide Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=259 icode= >, Distance: 2.032108783721924
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=25 icode= >, Distance: 23.907508850097656
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=80 icode= >, Distance: 25.500192642211914
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 126.74256134033203
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=27 icode= >, Distance: 111.11689758300781
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 109.41317749023438
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 119.7328109741211
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 121.54889678955078
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 143.20338439941406
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 127.87783813476562
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=259 icode= > - <Residue CYS het=  resseq=25 icode= >, Distance: 25.096988677978516
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=259 icode= > - <Residue CYS het=  resseq=80 icode= >, Distance: 26.723873138427734
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=259 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 126.2479248046875
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=259 icode= > - <Residue CYS het=  resseq=27 icode= >, Distance: 111.32504272460938
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=259 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 109.60352325439453
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=259 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 119.60832214355469
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=259 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 121.43924713134766
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=259 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 142.96722412109375
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=259 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 127.37700653076172
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=25 icode= > - <Residue CYS het=  resseq=80 icode= >, Distance: 2.0316238403320312
# Recorded disulfide Cys-Cys interaction: <Residue CYS het=  resseq=25 icode= > - <Residue CYS het=  resseq=80 icode= >, Distance: 2.0316238403320312
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=25 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 117.34461975097656
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=25 icode= > - <Residue CYS het=  resseq=27 icode= >, Distance: 93.89654541015625
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=25 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 92.39358520507812
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=25 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 106.77503204345703
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=25 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 108.43241882324219
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=25 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 129.67044067382812
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=25 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 118.69637298583984
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=80 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 118.07020568847656
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=80 icode= > - <Residue CYS het=  resseq=27 icode= >, Distance: 93.85092163085938
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=80 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 92.37679290771484
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=80 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 107.20655822753906
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=80 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 108.84549713134766
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=80 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 129.97048950195312
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=80 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 119.44207000732422
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=11 icode= > - <Residue CYS het=  resseq=27 icode= >, Distance: 49.13909149169922
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=11 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 48.28464889526367
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=11 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 24.125905990600586
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=11 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 24.731678009033203
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=11 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 29.445959091186523
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=11 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 2.0299205780029297
# Recorded disulfide Cys-Cys interaction: <Residue CYS het=  resseq=11 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 2.0299205780029297
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=27 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 2.0331497192382812
# Recorded disulfide Cys-Cys interaction: <Residue CYS het=  resseq=27 icode= > - <Residue CYS het=  resseq=76 icode= >, Distance: 2.0331497192382812
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=27 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 27.0892391204834
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=27 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 27.264537811279297
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=27 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 42.84236526489258
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=27 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 50.70918655395508
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=76 icode= > - <Residue CYS het=  resseq=97 icode= >, Distance: 26.479694366455078
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=76 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 26.800743103027344
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=76 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 43.217647552490234
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=76 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 49.86967849731445
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=97 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 2.027956962585449
# Recorded disulfide Cys-Cys interaction: <Residue CYS het=  resseq=97 icode= > - <Residue CYS het=  resseq=100 icode= >, Distance: 2.027956962585449
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=97 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 27.208423614501953
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=97 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 25.276355743408203
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=100 icode= > - <Residue CYS het=  resseq=117 icode= >, Distance: 25.954322814941406
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=100 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 25.81450653076172
# Checking Cys-Cys interaction: <Residue CYS het=  resseq=117 icode= > - <Residue CYS het=  resseq=11 icode= >, Distance: 30.231626510620117
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=90 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=133 icode= > - <Residue CYS het=  resseq=183 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=205 icode= > - <Residue CYS het=  resseq=244 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=92 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=144 icode= > - <Residue CYS het=  resseq=209 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=24 icode= > - <Residue CYS het=  resseq=65 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=82 icode= > - <Residue CYS het=  resseq=85 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=16 icode= > - <Residue CYS het=  resseq=52 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=72 icode= > - <Residue CYS het=  resseq=75 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=27 icode= > - <Residue CYS het=  resseq=76 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=97 icode= > - <Residue CYS het=  resseq=100 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=101 icode= > - <Residue CYS het=  resseq=164 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=203 icode= > - <Residue CYS het=  resseq=259 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=25 icode= > - <Residue CYS het=  resseq=80 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=11 icode= > - <Residue CYS het=  resseq=11 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=27 icode= > - <Residue CYS het=  resseq=76 icode= >
# Appended verified disulfide Cys-Cys interaction: <Residue CYS het=  resseq=97 icode= > - <Residue CYS het=  resseq=100 icode= >
# Appended verified non-disulfide Cys-Cys interaction: <Residue CYS het=  resseq=82 icode= > - <Residue CYS het=  resseq=97 icode= >
# Verified disulfide Cys-Cys interactions detected and will be saved to Excel.
# Verified non-disulfide Cys-Cys interactions detected and will be saved to Excel.
# Results have been saved to 'Interacting_Amino_Acids_and_Chains_7phr.xlsx'
